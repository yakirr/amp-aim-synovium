# %%
# Load required libraries
import synapseclient
import synapseutils
from pathlib import Path
import csv

# %%
syn = synapseclient.Synapse()
syn.login()
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (4.11.0) is available. Your version (4.10.0) can be upgraded by typing:
#    pip install --upgrade synapseclient
#
# Python Synapse Client version 4.11.0 release notes
#
# https://python-docs.synapse.org/news/
#
#
# Welcome, yakirreshef!

# %%
base = Path('/data/srlab/AMP_collab/data/early_disease_synovium/xenium')
data = [
    ['syn63926992', base / 'Xenium_RA-SYN/Level_1_Xenium_Output'],
    ['syn64009803', base / 'Xenium_PsD-SYN/Level_1_Xenium_Output'],
    ['syn65769643', base / 'Xenium_CTRL-SYN/Level_1_Xenium_Output']]

# %%
# download recursively
for syn_id, target in data:
    print(syn_id, '->', target)
    try:
        Path(target).mkdir(parents=True, exist_ok=True)
        all_files = synapseutils.syncFromSynapse(syn, entity=syn_id, path=target)
    except FileExistsError as e:
        print(e)
        pass
# Out:
# Downloading files: 100%|█████████▉| 269G/269G [1:23:30<00:00, 53.6MB/s]
# syn63926992 -> /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output
# [syn63926992:Level_1_Xenium Output]: Syncing Folder from Synapse.
# Downloading files: 100%|█████████▉| 269G/269G [1:23:50<00:00, 53.4MB/s]
# [syn64129944:output-XETG00150__0027107__slidearray0097__20241023__195946.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00150__0027107__slidearray0097__20241023__195946.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:24:31<00:00, 53.0MB/s]
# [syn64130063:output-XETG00392__0027093__slidearray0099__20241113__210855.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00392__0027093__slidearray0099__20241113__210855.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:24:50<00:00, 52.8MB/s]
# [syn64129975:output-XETG00392__0027248__slidearray0091__20241011__193809.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00392__0027248__slidearray0091__20241011__193809.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:25:23<00:00, 52.4MB/s]
# [syn64129996:output-XETG00392__0027249__slidearray0089__20241011__193808.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00392__0027249__slidearray0089__20241011__193808.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:26:14<00:00, 51.9MB/s]
# [syn64130174:output-XETG00392__0030554__slidearray0081__20241018__192235.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00392__0030554__slidearray0081__20241018__192235.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:27:27<00:00, 51.2MB/s]
# [syn64130342:output-XETG00392__0030701__slidearray0083__20241018__192235.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00392__0030701__slidearray0083__20241018__192235.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:27:31<00:00, 51.1MB/s]
# [syn64129916:output-XETG00150__0031015__slidearray0085__20241023__195946.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00150__0031015__slidearray0085__20241023__195946.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:28:27<00:00, 50.6MB/s]
# [syn64130100:output-XETG00150__0030961__slidearray0093__20241011__193120.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00150__0030961__slidearray0093__20241011__193120.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:29:55<00:00, 49.8MB/s]
# [syn64130392:output-XETG00150__0031100__slidearray0095__20241011__193120.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN/Level_1_Xenium_Output/output-XETG00150__0031100__slidearray0095__20241011__193120.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:29:55<00:00, 49.8MB/s]
# syn64009803 -> /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN/Level_1_Xenium_Output
# Downloading files: 100%|█████████▉| 269G/269G [1:29:55<00:00, 49.8MB/s]
# [syn64009803:Level_1_Xenium Output]: Syncing Folder from Synapse.
# Downloading files: 100%|█████████▉| 269G/269G [1:30:22<00:00, 49.5MB/s]
# [syn64824462:output-XETG00150__0045086__slidearray0112__20250210__022453.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN/Level_1_Xenium_Output/output-XETG00150__0045086__slidearray0112__20250210__022453.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:30:41<00:00, 49.4MB/s]
# [syn64824520:output-XETG00150__0044043__slidearray0114__20250210__022453.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN/Level_1_Xenium_Output/output-XETG00150__0044043__slidearray0114__20250210__022453.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:30:57<00:00, 49.2MB/s]
# [syn65931596:output-XETG00392__0059077__Slidearray0118__20250306__204353.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN/Level_1_Xenium_Output/output-XETG00392__0059077__Slidearray0118__20250306__204353.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:31:10<00:00, 49.1MB/s]
# [syn64823993:output-XETG00392__0044046__slidearry0108__20250210__022932.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN/Level_1_Xenium_Output/output-XETG00392__0044046__slidearry0108__20250210__022932.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:31:30<00:00, 48.9MB/s]
# [syn64824288:output-XETG00392__0045018__slidearray0110__20250210__022932.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN/Level_1_Xenium_Output/output-XETG00392__0045018__slidearray0110__20250210__022932.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:32:32<00:00, 48.4MB/s]
# [syn65931646:output-XETG00392__0059074__Slidearray0116__20250306__204353.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN/Level_1_Xenium_Output/output-XETG00392__0059074__Slidearray0116__20250306__204353.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:32:32<00:00, 48.4MB/s]
# syn65769643 -> /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN/Level_1_Xenium_Output
# Downloading files: 100%|█████████▉| 269G/269G [1:32:32<00:00, 48.4MB/s]
# [syn65769643:Level_1_Xenium output]: Syncing Folder from Synapse.
# Downloading files: 100%|█████████▉| 269G/269G [1:33:20<00:00, 48.0MB/s]
# [syn65772667:output-XETG00150__0045146__slidearray0106__20250124__220454.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN/Level_1_Xenium_Output/output-XETG00150__0045146__slidearray0106__20250124__220454.zip, skipping download.
# Downloading files: 100%|█████████▉| 269G/269G [1:34:21<00:00, 47.4MB/s]
# [syn65772841:output-XETG00150__0045020__slidearray0104__20250124__220454.zip]: Found existing file at /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN/Level_1_Xenium_Output/output-XETG00150__0045020__slidearray0104__20250124__220454.zip, skipping download.
