# %%
import os
from datetime import date
import synapseclient
import synapseutils
from synapseclient import Project

syn = synapseclient.Synapse()
syn.login()
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (4.13.0) is available. Your version (4.10.0) can be upgraded by typing:
#    pip install --upgrade synapseclient
#
# Python Synapse Client version 4.13.0 release notes
#
# https://python-docs.synapse.org/news/
#
#
# Welcome, yakirreshef!

# %% [markdown]
# # Utility functions

# %%
def make_manifest(uploads, dry_run=False):
    for remote_project_id, LOCAL_PROJECT_DIRECTORY, LOCAL_FILE_MANIFEST in uploads:
        print(LOCAL_PROJECT_DIRECTORY)
        print(LOCAL_FILE_MANIFEST)

        # Create a manifest TSV file to upload data in bulk
        # Note: When this command is run it will re-create your directory structure within
        # Synapse. Be aware of this before running this command.
        # If folders with the exact names already exists in Synapse, those folders will be used.
        if not dry_run:
            synapseutils.generate_sync_manifest(
                syn=syn,
                directory_path=LOCAL_PROJECT_DIRECTORY,
                parent_id=remote_project_id,
                manifest_path=LOCAL_FILE_MANIFEST
            )

# %%
def do_upload(uploads):
    for remote_project_id, _, LOCAL_FILE_MANIFEST in uploads:
        synapseutils.syncToSynapse(
            syn=syn, manifestFile=LOCAL_FILE_MANIFEST, sendMessages=True
        )

# %% [markdown]
# # Upload control files

# %%
uploads = [
    ('syn75383138', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN-EDP1/Level_2', 'control_Level_2_manifest.tsv'),
    ('syn75383140', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN-EDP1/Level_3', 'control_Level_3_manifest.tsv'),
    ('syn75383141', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN-EDP1/Level_4', 'control_Level_4_manifest.tsv'),
]

# %%
make_manifest(uploads)
# Out:
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN-EDP1/Level_2
# control_Level_2_manifest.tsv
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN-EDP1/Level_3
# control_Level_3_manifest.tsv
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_CTRL-SYN-EDP1/Level_4
# control_Level_4_manifest.tsv

# %%
do_upload(uploads)
# Out:
# Validation and upload of: control_Level_2_manifest.tsv
# Validating columns of manifest...
# Validating that all paths exist...
# Validating that all files are unique...
# Validating that all the files are not empty...
# Validating file names...
# Validating provenance...
# Validating that parents exist and are containers...
# We are about to upload 6 files with a total size of 2195102217.
# Uploading 6 files: 100%|██████████| 2.20G/2.20G [00:31<00:00, 70.4MB/s]
# Validation and upload of: control_Level_3_manifest.tsv
# Validating columns of manifest...
# Validating that all paths exist...
# Validating that all files are unique...
# Validating that all the files are not empty...
# Validating file names...
# Validating provenance...
# Validating that parents exist and are containers...
# We are about to upload 12 files with a total size of 2803990775.
# Uploading 12 files: 100%|██████████| 2.80G/2.80G [00:38<00:00, 72.0MB/s]
# Validation and upload of: control_Level_4_manifest.tsv
# ...

# %% [markdown]
# # Upload RA EDP1 files

# %%
uploads = [
    ('syn75383162', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP1/Level_2', 'ra-edp1_Level_2_manifest.tsv'),
    ('syn75383159', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP1/Level_3', 'ra-edp1_Level_3_manifest.tsv'),
    ('syn75383158', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP1/Level_4', 'ra-edp1_Level_4_manifest.tsv'),
]

# %%
make_manifest(uploads)
# Out:
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP1/Level_2
# ra-edp1_Level_2_manifest.tsv
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP1/Level_3
# ra-edp1_Level_3_manifest.tsv
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP1/Level_4
# ra-edp1_Level_4_manifest.tsv

# %%
do_upload(uploads)
# Out:
# Validation and upload of: ./ra_edp1_manifest.tsv
# Validating columns of manifest...
# Validating that all paths exist...
# Validating that all files are unique...
# Validating that all the files are not empty...
# Validating file names...
# Validating provenance...
# Validating that parents exist and are containers...
# We are about to upload 26 files with a total size of 932256979.
# Uploading 26 files: 100%|██████████| 932M/932M [00:18<00:00, 50.5MB/s]

# %% [markdown]
# # Upload PsA EDP1 files

# %%
uploads = [
    ('syn75383151', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN-EDP1/Level_2', 'psd-edp1_Level_2_manifest.tsv'),
    ('syn75383154', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN-EDP1/Level_3', 'psd-edp1_Level_3_manifest.tsv'),
    ('syn75383155', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN-EDP1/Level_4', 'psd-edp1_Level_4_manifest.tsv'),
]

# %%
make_manifest(uploads)
# Out:
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN-EDP1/Level_2
# psd-edp1_Level_2_manifest.tsv
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN-EDP1/Level_3
# psd-edp1_Level_3_manifest.tsv
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_PsD-SYN-EDP1/Level_4
# psd-edp1_Level_4_manifest.tsv

# %%
do_upload(uploads)
# Out:
# Validation and upload of: ./psa_edp1_manifest.tsv
# Validating columns of manifest...
# Validating that all paths exist...
# Validating that all files are unique...
# Validating that all the files are not empty...
# Validating file names...
# Validating provenance...
# Validating that parents exist and are containers...
# We are about to upload 22 files with a total size of 492563837.
# Uploading 22 files: 100%|██████████| 493M/493M [00:12<00:00, 40.2MB/s]

# %% [markdown]
# # Upload RA EDP2 files

# %%
uploads = [
    ('syn75383169', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP2/Level_2', 'ra-edp2_Level_2_manifest.tsv'),
    ('syn75383170', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP2/Level_3', 'ra-edp2_Level_3_manifest.tsv'),
    ('syn75383175', '/data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP2/Level_4', 'ra-edp2_Level_4_manifest.tsv'),
]

# %%
make_manifest(uploads)
# Out:
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP2/Level_2
# ra-edp2_Level_2_manifest.tsv
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP2/Level_3
# ra-edp2_Level_3_manifest.tsv
# /data/srlab/AMP_collab/data/early_disease_synovium/xenium/Xenium_RA-SYN-EDP2/Level_4
# ra-edp2_Level_4_manifest.tsv

# %%
do_upload(uploads)
# Out:
# Validation and upload of: ./ra_edp2_manifest.tsv
# Validating columns of manifest...
# Validating that all paths exist...
# Validating that all files are unique...
# Validating that all the files are not empty...
# Validating file names...
# Validating provenance...
# Validating that parents exist and are containers...
# We are about to upload 48 files with a total size of 9535383367.
# Uploading 48 files: 100%|██████████| 9.54G/9.54G [02:50<00:00, 55.9MB/s]
